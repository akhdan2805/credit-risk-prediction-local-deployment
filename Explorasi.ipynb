# %% [markdown]
# **UAS MODEL DEPLOYMENT SEMESTER 4 2025/2026**
#
# **NAMA: MUHAMMAD AKHDAN ATHALLAH**
#
# **NIM: 2802446560**
#
# **LINK VIDEO PENJELASAN: https://youtu.be/X_iOk4f_cEg**
#
# **TIMESTAMP VIDEO ADA DI DESKRIPSI YOUTUBE UNTUK MEMPERMUDAH**
#
# **JIKA TERDAPAT MASALAH PADA VIDEO: `0878-1577-8933`**

# %% [markdown]
# # **SOAL GENAP LAKI-LAKI (DATA C)**

# %% [markdown]
# ## **LOAD & INSPECT DATA**

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
pd.set_option('display.max_columns', None)

df = pd.read_csv("C:/Users/PC/Downloads/UAS Semester 4 2025 2026/Model Deployment/data_C.csv")
df.head(10)
# Out:
#    Unnamed: 0       ID Customer_ID   Month            Name Age          SSN  \
# 0           0  0x20419  CUS_0x36e1  August         Gellero  35  132-77-4921
# 1           1   0x4579  CUS_0x2a61  August             NaN  46  753-68-0048
# 2           2  0x1b923  CUS_0x788b    June    Ben Klaymane  19  276-42-6585
# 3           3   0x8ac9  CUS_0x5534   April          Aubinr  39  246-34-3138
# 4           4  0x24a41  CUS_0x104f   April           Markm  20  264-84-8069
# 5           5  0x16099  CUS_0x6573  August          Jamesp  34  682-25-4861
# 6           6  0x23e35  CUS_0xb3c2   April        Shirbonv  35    #F%$D@*&8
# 7           7  0x19cd4  CUS_0xba0b    July   Leah Schnurro  34  165-76-8590
# 8           8  0x14c0d  CUS_0x38d8   April  Nishant Kumart  24  467-02-8866
# 9           9  0x1298f  CUS_0x51a1    June             NaN  45  959-74-6872
#
#       Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN',
#        'Occupation', 'Annual_Income', 'Monthly_Inhand_Salary',
#        'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan',
#        'Type_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment',
#        'Changed_Credit_Limit', 'Num_Credit_Inquiries', 'Credit_Mix',
#        'Outstanding_Debt', 'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
df = df.drop(['Unnamed: 0', 'ID', 'Customer_ID', 'Name', 'SSN', 'Month'],axis=1)

# %% [markdown]
# - `Unnamed: 0` = Hanyak index
# - `ID` = Identifier
# - `Customer_ID` = Identifier
# - `Name` = Informasi pribadi, tidak mempengaruhi prediksi
# - `SSN` = Informasi pribadi, tidak mempengaruhi prediksi
# - `Month` = Bulan pencatatan tidak mempengaruhi prediksi

# %%
df.head(10)
# Out:
#   Age     Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0  35     Journalist      20364.57            1626.047500                  6
# 1  46        Teacher       9786.86             951.571667                  9
# 2  19        _______     146880.84           12372.070000                  1
# 3  39      Developer      23200.82                    NaN                  3
# 4  20      Architect     11336.835             992.736250                  4
# 5  34         Doctor      8922.155             957.512917                  6
# 6  35  Media_Manager     20487.905                    NaN                  4
# 7  34     Accountant      54265.54                    NaN                  3
# 8  24     Accountant     101114.73            8679.227500                  6
# 9  45   Entrepreneur      63306.54            5260.545000                  4
#
#    Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 0                8             32           3
# ...

# %% [markdown]
# ## **1. Exploratory Data Analysis (EDA)**

# %%
df.shape
# Out:
# (25000, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       25000 non-null  object
#  1   Occupation                25000 non-null  object
#  2   Annual_Income             25000 non-null  object
#  3   Monthly_Inhand_Salary     21164 non-null  float64
#  4   Num_Bank_Accounts         25000 non-null  int64
#  5   Num_Credit_Card           25000 non-null  int64
#  6   Interest_Rate             25000 non-null  int64
#  7   Num_of_Loan               25000 non-null  object
#  8   Type_of_Loan              22148 non-null  object
#  9   Delay_from_due_date       25000 non-null  int64
#  10  Num_of_Delayed_Payment    23208 non-null  object
#  11  Changed_Credit_Limit      25000 non-null  object
#  12  Num_Credit_Inquiries      24528 non-null  float64
# ...

# %% [markdown]
# Variabel Angka Salah Data Type:
# - `Age` object 25000
# - `Annual_Income` object 25000
# - `Num_of_Loan` object 25000
# - `Num_of_Delayed_Payment` object 23208
# - `Changed_Credit_Limit` object 25000
# - `Outstanding_Debt` object 25000
# - `Amount_invested_monthly` object 23866

# %% [markdown]
# ### **Casting Kesalahan Data Type**

# %%
# Cari Kesalahan Age
mask = pd.to_numeric(df['Age'], errors='coerce').isna() & df['Age'].notna()
bad_Age = df.loc[mask, 'Age'].unique()
print(f"Jumlah variasi nilai bermasalah: {len(bad_Age)}")
print(bad_Age)

# Fix Age
df['Age'] = df['Age'].str.strip('_')
df['Age'] = pd.to_numeric(df['Age'])

print()
print(f"Tipe Data Setelah Diperbaiki: {df['Age'].dtype}")
# Out:
# Jumlah variasi nilai bermasalah: 67
# ['28_' '53_' '26_' '43_' '15_' '2756_' '19_' '29_' '32_' '18_' '25_' '34_'
#  '50_' '41_' '6744_' '38_' '16_' '20_' '36_' '48_' '55_' '21_' '23_' '45_'
#  '24_' '27_' '3307_' '30_' '31_' '39_' '49_' '22_' '51_' '40_' '44_' '54_'
#  '17_' '2329_' '42_' '37_' '52_' '47_' '6799_' '33_' '1188_' '14_' '35_'
#  '46_' '56_' '6381_' '3998_' '5769_' '2846_' '3988_' '780_' '2159_' '737_'
#  '3712_' '3339_' '7316_' '1794_' '2171_' '8153_' '2155_' '5373_' '6666_'
#  '4445_']
#
# Tipe Data Setelah Diperbaiki: int64

# %%
# Cari Kesalahan Annual_Income
mask = pd.to_numeric(df['Annual_Income'], errors='coerce').isna() & df['Annual_Income'].notna()
bad_Annual_Income = df.loc[mask, 'Annual_Income'].unique()
print(f"Jumlah variasi nilai bermasalah: {len(bad_Annual_Income)}")
print(bad_Annual_Income)

# Fix Annual_Income
df['Annual_Income'] = df['Annual_Income'].str.strip('_')
df['Annual_Income'] = pd.to_numeric(df['Annual_Income'])

print()
print(f"Tipe Data Setelah Diperbaiki: {df['Annual_Income'].dtype}")
# Out:
# Jumlah variasi nilai bermasalah: 1670
# ['43534.9_' '28828.86_' '7780.49_' ... '43985.8_' '73509.02_' '21734.19_']
#
# Tipe Data Setelah Diperbaiki: float64

# %%
# Cari Kesalahan Num_of_Loan
mask = pd.to_numeric(df['Num_of_Loan'], errors='coerce').isna() & df['Num_of_Loan'].notna()
bad_Num_of_Loan = df.loc[mask, 'Num_of_Loan'].unique()
print(f"Jumlah variasi nilai bermasalah: {len(bad_Num_of_Loan)}")
print(bad_Num_of_Loan)

# Fix Num_of_Loan
df['Num_of_Loan'] = df['Num_of_Loan'].str.strip('_')
df['Num_of_Loan'] = pd.to_numeric(df['Num_of_Loan'])

print()
print(f"Tipe Data Setelah Diperbaiki: {df['Num_of_Loan'].dtype}")
# Out:
# Jumlah variasi nilai bermasalah: 14
# ['0_' '4_' '2_' '9_' '1_' '5_' '3_' '6_' '7_' '8_' '131_' '696_' '92_'
#  '1459_']
#
# Tipe Data Setelah Diperbaiki: int64

# %%
# Cari Kesalahan Num_of_Delayed_Payment
mask = pd.to_numeric(df['Num_of_Delayed_Payment'], errors='coerce').isna() & df['Num_of_Delayed_Payment'].notna()
bad_Num_of_Delayed_Payment = df.loc[mask, 'Num_of_Delayed_Payment'].unique()
print(f"Jumlah variasi nilai bermasalah: {len(bad_Num_of_Delayed_Payment)}")
print(bad_Num_of_Delayed_Payment)

# Fix Num_of_Delayed_Payment
df['Num_of_Delayed_Payment'] = df['Num_of_Delayed_Payment'].str.strip('_')
df['Num_of_Delayed_Payment'] = pd.to_numeric(df['Num_of_Delayed_Payment'])

print()
print(f"Tipe Data Setelah Diperbaiki: {df['Num_of_Delayed_Payment'].dtype}")
# Out:
# Jumlah variasi nilai bermasalah: 35
# ['19_' '8_' '17_' '2_' '7_' '15_' '4_' '12_' '16_' '21_' '22_' '11_' '18_'
#  '14_' '9_' '28_' '20_' '25_' '3_' '0_' '13_' '1_' '10_' '23_' '24_'
#  '1323_' '6_' '5_' '1473_' '-2_' '183_' '27_' '-1_' '848_' '2237_']
#
# Tipe Data Setelah Diperbaiki: float64

# %%
# Cari Kesalahan Changed_Credit_Limit
mask = pd.to_numeric(df['Changed_Credit_Limit'], errors='coerce').isna() & df['Changed_Credit_Limit'].notna()
bad_Changed_Credit_Limit = df.loc[mask, 'Changed_Credit_Limit'].unique()
print(f"Jumlah variasi nilai bermasalah: {len(bad_Changed_Credit_Limit)}")
print(bad_Changed_Credit_Limit)

# Fix Changed_Credit_Limit
df['Changed_Credit_Limit'] = pd.to_numeric(df['Changed_Credit_Limit'], errors='coerce')

print()
print(f"Tipe Data Setelah Diperbaiki: {df['Changed_Credit_Limit'].dtype}")
# Out:
# Jumlah variasi nilai bermasalah: 1
# ['_']
#
# Tipe Data Setelah Diperbaiki: float64

# %%
# Cari Kesalahan Outstanding_Debt
mask = pd.to_numeric(df['Outstanding_Debt'], errors='coerce').isna() & df['Outstanding_Debt'].notna()
bad_Outstanding_Debt = df.loc[mask, 'Outstanding_Debt'].unique()
print(f"Jumlah variasi nilai bermasalah: {len(bad_Outstanding_Debt)}")
print(bad_Outstanding_Debt)

# Fix Outstanding_Debt
df['Outstanding_Debt'] = df['Outstanding_Debt'].str.strip('_')
df['Outstanding_Debt'] = pd.to_numeric(df['Outstanding_Debt'])

print()
print(f"Tipe Data Setelah Diperbaiki: {df['Outstanding_Debt'].dtype}")
# Out:
# Jumlah variasi nilai bermasalah: 266
# ['1449.78_' '1571.26_' '810.8_' '3818.57_' '783.52_' '443.32_' '926.62_'
#  '1480.12_' '897.82_' '27.19_' '888.02_' '2695.77_' '1393.85_' '469.39_'
#  '816.95_' '4632.72_' '182.91_' '1188.75_' '2517.66_' '1265.83_' '836.67_'
#  '4525.71_' '2813.15_' '891.96_' '512.83_' '863.48_' '817.66_' '1460.07_'
#  '1746.37_' '912.63_' '970.11_' '1464.74_' '542.56_' '731.37_' '3651.35_'
#  '300.47_' '1600.43_' '1233.96_' '754.55_' '1192.4_' '1394.91_' '4622.5_'
#  '2608.97_' '876.74_' '3571.7_' '4854.6_' '1221.11_' '2781.7_' '506.71_'
#  '1169.13_' '807.65_' '381.06_' '4770.24_' '94.75_' '484.16_' '880.43_'
#  '1429.96_' '494.51_' '1909.03_' '1539.17_' '613.93_' '725.13_' '1464.77_'
#  '282.06_' '3562.24_' '186.6_' '1112.8_' '1549.11_' '1215.11_' '1912.96_'
#  '1392.71_' '678.58_' '2352.38_' '3057.46_' '561.21_' '1279.86_' '656.7_'
#  '587.16_' '42.69_' '297.64_' '1543.16_' '1042.25_' '2032.49_' '3356.86_'
# ...

# %%
# Cari Kesalahan Amount_invested_monthly
mask = pd.to_numeric(df['Amount_invested_monthly'], errors='coerce').isna() & df['Amount_invested_monthly'].notna()
bad_Amount_invested_monthly = df.loc[mask, 'Amount_invested_monthly'].unique()
print(f"Jumlah variasi nilai bermasalah: {len(bad_Amount_invested_monthly)}")
print(bad_Amount_invested_monthly)

# Fix Amount_invested_monthly
df['Amount_invested_monthly'] = df['Amount_invested_monthly'].str.strip('_')
df['Amount_invested_monthly'] = pd.to_numeric(df['Amount_invested_monthly'])

print()
print(f"Tipe Data Setelah Diperbaiki: {df['Amount_invested_monthly'].dtype}")
# Out:
# Jumlah variasi nilai bermasalah: 1
# ['__10000__']
#
# Tipe Data Setelah Diperbaiki: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       25000 non-null  int64
#  1   Occupation                25000 non-null  object
#  2   Annual_Income             25000 non-null  float64
#  3   Monthly_Inhand_Salary     21164 non-null  float64
#  4   Num_Bank_Accounts         25000 non-null  int64
#  5   Num_Credit_Card           25000 non-null  int64
#  6   Interest_Rate             25000 non-null  int64
#  7   Num_of_Loan               25000 non-null  int64
#  8   Type_of_Loan              22148 non-null  object
#  9   Delay_from_due_date       25000 non-null  int64
#  10  Num_of_Delayed_Payment    23208 non-null  float64
#  11  Changed_Credit_Limit      24482 non-null  float64
#  12  Num_Credit_Inquiries      24528 non-null  float64
# ...

# %% [markdown]
# Notes: Pastikan Dtype sudah benar dan tidak ada jumlah data yang berubah kecuali **Changed_Credit_Limit** karena dirubah menjadi NaN
# - `Age` object 25000 -> int64 25000
# - `Annual_Income` object 25000 -> float64 25000
# - `Num_of_Loan` object 25000 -> int64 25000
# - `Num_of_Delayed_Payment` object 23208 -> float64 23208
# - `Changed_Credit_Limit` object 25000 -> float64 24482
# - `Outstanding_Debt` object 25000 -> float64 25000
# - `Amount_invested_monthly` object 23866 -> float64 23866

# %% [markdown]
# ### **Cek Duplikat**

# %%
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ### **Filter Data Anomali**

# %% [markdown]
# #### **Data Kategorik**

# %%
cat_cols = df.select_dtypes(include='object').columns
for col in cat_cols:
    print(f"=== {col} ===")
    print(df[col].unique())
    print()
# Out:
# === Occupation ===
# ['Journalist' 'Teacher' '_______' 'Developer' 'Architect' 'Doctor'
#  'Media_Manager' 'Accountant' 'Entrepreneur' 'Lawyer' 'Writer' 'Engineer'
#  'Manager' 'Musician' 'Scientist' 'Mechanic']
#
# === Type_of_Loan ===
# ['Personal Loan, Student Loan, and Mortgage Loan'
#  'Personal Loan, and Student Loan' 'Auto Loan' ...
#  'Student Loan, Debt Consolidation Loan, Home Equity Loan, Home Equity Loan, Not Specified, Mortgage Loan, and Student Loan'
#  'Auto Loan, Not Specified, Auto Loan, Not Specified, Payday Loan, and Student Loan'
#  'Home Equity Loan, Not Specified, Home Equity Loan, Debt Consolidation Loan, Mortgage Loan, and Debt Consolidation Loan']
#
# === Credit_Mix ===
# ['Standard' 'Good' 'Bad' '_']
#
# === Credit_History_Age ===
# ['9 Years and 8 Months' nan '24 Years and 3 Months'
#  '17 Years and 7 Months' '14 Years and 7 Months' '2 Years and 4 Months'
#  '20 Years and 11 Months' '23 Years and 5 Months' '28 Years and 2 Months'
# ...

# %%
def parse_loans(text):
    if pd.isna(text):
        return []
    cleaned = text.replace(', and ', ', ').replace(' and ', ', ')
    return [loan.strip() for loan in cleaned.split(', ')]

all_loans_lists = df['Type_of_Loan'].apply(parse_loans)
unique_loan_types = set()
for loans in all_loans_lists:
    unique_loan_types.update(loans)

print(sorted(unique_loan_types))
print(f"\nJumlah tipe pinjaman unik: {len(unique_loan_types)}")
# Out:
# ['Auto Loan', 'Credit-Builder Loan', 'Debt Consolidation Loan', 'Home Equity Loan', 'Mortgage Loan', 'Not Specified', 'Payday Loan', 'Personal Loan', 'Student Loan']
#
# Jumlah tipe pinjaman unik: 9

# %%
# Occupation
df['Occupation'] = df['Occupation'].replace('_______', 'Unknown')
print(df['Occupation'].value_counts(dropna=False))
# Out:
# Occupation
# Unknown          1765
# Lawyer           1642
# Mechanic         1621
# Teacher          1618
# Developer        1580
# Journalist       1568
# Scientist        1558
# Accountant       1553
# Media_Manager    1552
# Architect        1550
# Engineer         1549
# Entrepreneur     1511
# Doctor           1504
# Manager          1497
# Musician         1491
# Writer           1441
# Name: count, dtype: int64

# %%
# Credit_Mix
df['Credit_Mix'] = df['Credit_Mix'].replace('_', 'Unknown')
print(df['Credit_Mix'].value_counts(dropna=False))
# Out:
# Credit_Mix
# Standard    9170
# Good        6123
# Unknown     4926
# Bad         4781
# Name: count, dtype: int64

# %%
# Payment_of_Min_Amount
df['Payment_of_Min_Amount'] = df['Payment_of_Min_Amount'].replace('NM', 'Unknown')
print(df['Payment_of_Min_Amount'].value_counts(dropna=False))
# Out:
# Payment_of_Min_Amount
# Yes        13082
# No          8971
# Unknown     2947
# Name: count, dtype: int64

# %%
# Payment_Behaviour
df['Payment_Behaviour'] = df['Payment_Behaviour'].replace('!@9#%8', 'Unknown')
print(df['Payment_Behaviour'].value_counts(dropna=False))
# Out:
# Payment_Behaviour
# Low_spent_Small_value_payments      6377
# High_spent_Medium_value_payments    4401
# Low_spent_Medium_value_payments     3475
# High_spent_Large_value_payments     3370
# High_spent_Small_value_payments     2781
# Low_spent_Large_value_payments      2645
# Unknown                             1951
# Name: count, dtype: int64

# %% [markdown]
# #### **Data Numerik (<=5% -> Drop, >5% -> Impute NaN)**

# %%
df.describe()
# Out:
#                 Age  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count  25000.000000   2.500000e+04           21164.000000       25000.000000
# mean     108.102760   1.623404e+05            4189.505970          18.075360
# std      670.342409   1.343255e+06            3208.575501         122.375374
# min     -500.000000   7.005930e+03             303.645417          -1.000000
# 25%       24.000000   1.920549e+04            1611.188333           3.000000
# 50%       33.000000   3.731332e+04            3071.424583           6.000000
# 75%       42.000000   7.271220e+04            5941.093333           7.000000
# max     8697.000000   2.416001e+07           15204.633333        1789.000000
#
#        Num_Credit_Card  Interest_Rate   Num_of_Loan  Delay_from_due_date  \
# count     25000.000000   25000.000000  25000.000000         25000.000000
# mean         22.238000      75.407480      3.118400            20.988400
# ...

# %%
num_cols_check = df.select_dtypes(include=['int64', 'float64']).columns.drop(['Annual_Income', 'Monthly_Inhand_Salary'])

df[num_cols_check].boxplot()
plt.show()

# %% [markdown]
# Variabel Terdapat Nilai Mustahil:
# - `Age`
# - `Num_Bank_Accounts`
# - `Num_of_Loan`
# - `Delay_from_due_date`
# - `Num_of_Delayed_Payment`
#
# Variabel Terdapat Nilai Ekstrem:
# - `Interest_Rate`
# - `Num_Credit_Card`
# - `Num_Credit_Inquiries`
# - `Annual_Income`
# - `Amount_invested_monthly`
# - `Total_EMI_per_month`

# %% [markdown]
# ##### **FILTER NILAI MUSTAHIL**

# %%
# Cek Jumlah Anomali Age
print(df['Age'].quantile([0.90, 0.95, 0.96, 0.97, 0.98, 0.99]))

mask_anomali = (df['Age'] < 18) | (df['Age'] > 100) | df['Age'].isna()
print(f"Jumlah anomali Age : {mask_anomali.sum()} baris ({mask_anomali.mean()*100:.2f}%)")

# Keputusan Penanganan (Impute NaN di atas 5%)
df.loc[(df['Age'] < 18) | (df['Age'] > 100), 'Age'] = np.nan
# Out:
# 0.90      50.00
# 0.95      53.00
# 0.96      54.00
# 0.97      55.00
# 0.98      56.00
# 0.99    3854.02
# Name: Age, dtype: float64
# Jumlah anomali Age : 2172 baris (8.69%)

# %%
# Cek Jumlah Anomali Num_Bank_Accounts
print(df['Num_Bank_Accounts'].quantile([0.90, 0.95, 0.96, 0.97, 0.98, 0.99]))

mask_anomali = (df['Num_Bank_Accounts'] < 1) | (df['Num_Bank_Accounts'] > 15) | df['Num_Bank_Accounts'].isna()
print(f"Jumlah anomali Num_Bank_Accounts : {mask_anomali.sum()} baris ({mask_anomali.mean()*100:.2f}%)")

# Keputusan Penanganan (Impute NaN di atas 5%)
df.loc[(df['Num_Bank_Accounts'] < 1) | (df['Num_Bank_Accounts'] > 15), 'Num_Bank_Accounts'] = np.nan
# Out:
# 0.90      9.00
# 0.95     10.00
# 0.96     10.00
# 0.97     10.00
# 0.98     10.00
# 0.99    549.07
# Name: Num_Bank_Accounts, dtype: float64
# Jumlah anomali Num_Bank_Accounts : 1466 baris (5.86%)

# %%
# Cek Jumlah Anomali Num_of_Loan
print(df['Num_of_Loan'].quantile([0.90, 0.95, 0.96, 0.97, 0.98, 0.99, 0.9999]))

mask_anomali = (df['Num_of_Loan'] < 0) | (df['Num_of_Loan'] > 10) | df['Num_of_Loan'].isna()
print(f"Jumlah anomali Num_of_Loan : {mask_anomali.sum()} baris ({mask_anomali.mean()*100:.2f}%)")

# Keputusan Penanganan (Drop Data di bawah 5%)
df = df[(df['Num_of_Loan'] >= 0) & (df['Num_of_Loan'] <= 10)]
# Out:
# 0.9000       7.0000
# 0.9500       8.0000
# 0.9600       8.0000
# 0.9700       9.0000
# 0.9800       9.0000
# 0.9900       9.0000
# 0.9999    1467.5013
# Name: Num_of_Loan, dtype: float64
# Jumlah anomali Num_of_Loan : 1108 baris (4.43%)

# %%
# Cek Jumlah Anomali Delay_from_due_date
print(df['Delay_from_due_date'].quantile([0.90, 0.95, 0.96, 0.97, 0.98, 0.99]))

mask_anomali = (df['Delay_from_due_date'] < 0) | df['Delay_from_due_date'].isna()
print(f"Jumlah anomali Delay_from_due_date : {mask_anomali.sum()} baris ({mask_anomali.mean()*100:.2f}%)")

# Keputusan Penanganan (Drop Data di bawah 5%)
df = df[(df['Delay_from_due_date'] >= 0)]
# Out:
# 0.90    45.0
# 0.95    54.0
# 0.96    55.0
# 0.97    57.0
# 0.98    59.0
# 0.99    61.0
# Name: Delay_from_due_date, dtype: float64
# Jumlah anomali Delay_from_due_date : 122 baris (0.51%)

# %%
# Cek Jumlah Anomali Num_of_Delayed_Payment
print(df['Num_of_Delayed_Payment'].quantile([0.90, 0.95, 0.96, 0.97, 0.98, 0.99, 0.9999]))

mask_anomali = (df['Num_of_Delayed_Payment'] < 0) | (df['Num_of_Delayed_Payment'] > 30) | df['Num_of_Delayed_Payment'].isna()
print(f"Jumlah anomali Num_of_Delayed_Payment : {mask_anomali.sum()} baris ({mask_anomali.mean()*100:.2f}%)")

# Keputusan Penanganan (Impute NaN di atas 5%)
df.loc[(df['Num_of_Delayed_Payment'] < 0) | (df['Num_of_Delayed_Payment'] > 30), 'Num_of_Delayed_Payment'] = np.nan
# Out:
# 0.9000      21.0000
# 0.9500      24.0000
# 0.9600      24.0000
# 0.9700      25.0000
# 0.9800      25.0000
# 0.9900      27.0000
# 0.9999    4281.1684
# Name: Num_of_Delayed_Payment, dtype: float64
# Jumlah anomali Num_of_Delayed_Payment : 1999 baris (8.41%)

# %% [markdown]
# ##### **FILTER NILAI EKSTREM**

# %%
# Cek Jumlah Anomali Interest_Rate
print(df['Interest_Rate'].quantile([0.90, 0.95, 0.96, 0.97, 0.98, 0.99]))

mask_anomali = (df['Interest_Rate'] > 35) | (df['Interest_Rate'].isna())
print(f"Jumlah anomali: {mask_anomali.sum():,} baris ({mask_anomali.mean()*100:.2f}%)")

# Keputusan Penanganan (Drop Data di bawah 5%)
df = df[(df['Interest_Rate'] <= 35)]
# Out:
# 0.90      29.00
# 0.95      33.00
# 0.96      33.00
# 0.97      34.00
# 0.98     398.54
# 0.99    2941.51
# Name: Interest_Rate, dtype: float64
# Jumlah anomali: 512 baris (2.15%)

# %%
# Cek Jumlah Anomali Num_Credit_Card
print(df['Num_Credit_Card'].quantile([0.90, 0.95, 0.96, 0.97, 0.98, 0.99]))

mask_anomali = (df['Num_Credit_Card'] > 15) | (df['Num_Credit_Card'].isna())
print(f"Jumlah anomali: {mask_anomali.sum():,} baris ({mask_anomali.mean()*100:.2f}%)")

# Keputusan Penanganan (Drop Data di bawah 5%)
df = df[(df['Num_Credit_Card'] <= 15)]
# Out:
# 0.90      9.00
# 0.95     10.00
# 0.96     10.00
# 0.97     10.00
# 0.98    170.16
# 0.99    816.86
# Name: Num_Credit_Card, dtype: float64
# Jumlah anomali: 522 baris (2.24%)

# %%
# Cek Jumlah Anomali Num_Credit_Inquiries
print(df['Num_Credit_Inquiries'].quantile([0.90, 0.95, 0.96, 0.97, 0.98, 0.99]))

mask_anomali = (df['Num_Credit_Inquiries'] > 20) | (df['Num_Credit_Inquiries'].isna())
print(f"Jumlah anomali: {mask_anomali.sum():,} baris ({mask_anomali.mean()*100:.2f}%)")

# Keputusan Penanganan (Drop Data di bawah 5%)
df = df[(df['Num_Credit_Inquiries'] <= 20)]
# Out:
# 0.90      12.00
# 0.95      13.00
# 0.96      14.00
# 0.97      15.00
# 0.98      17.00
# 0.99    1154.04
# Name: Num_Credit_Inquiries, dtype: float64
# Jumlah anomali: 827 baris (3.64%)

# %%
# Cek Jumlah Anomali Annual_Income
print(df['Annual_Income'].quantile([0.991, 0.995, 0.999, 0.9999]))

mask_anomali = (df['Annual_Income'] > 200000) | (df['Annual_Income'].isna())
print(f"Jumlah anomali: {mask_anomali.sum():,} baris ({mask_anomali.mean()*100:.2f}%)")

# Keputusan Penanganan (Drop Data di bawah 5%)
df = df[(df['Annual_Income'] <= 200000)]
# Out:
# 0.9910    1.793170e+05
# 0.9950    1.034057e+07
# 0.9990    2.164631e+07
# 0.9999    2.388668e+07
# Name: Annual_Income, dtype: float64
# Jumlah anomali: 188 baris (0.86%)

# %%
# Cek Jumlah Anomali Amount_invested_monthly
df['monthly_income'] = df['Annual_Income'] / 12
df['invest_ratio'] = df['Amount_invested_monthly'] / df['monthly_income']

suspicious = df[df['invest_ratio'] > 1]
print(f"\nJumlah baris invest > income bulanan: {len(suspicious):,} ({len(suspicious)/len(df)*100:.2f}%)")

mask_anomali = (df['invest_ratio'] > 1) | (df['Amount_invested_monthly'].isna())
print(f"Jumlah anomali: {mask_anomali.sum():,} baris ({mask_anomali.mean()*100:.2f}%)")

# Keputusan Penanganan (Impute NaN di atas 5%)
df.loc[df['invest_ratio'] > 1, 'Amount_invested_monthly'] = np.nan

df.drop(columns=['monthly_income', 'invest_ratio'], inplace=True)
# Out:
# Jumlah baris invest > income bulanan: 842 (3.88%)
# Jumlah anomali: 1,835 baris (8.45%)

# %%
# Cek Jumlah Anomali Total_EMI_per_month
df['monthly_income'] = df['Annual_Income'] / 12
df['emi_ratio'] = df['Total_EMI_per_month'] / df['monthly_income']

suspicious = df[df['emi_ratio'] > 1]
print(f"\nJumlah baris EMI > income bulanan: {len(suspicious):,} ({len(suspicious)/len(df)*100:.2f}%)")

mask_anomali = (df['emi_ratio'] > 1) | (df['Total_EMI_per_month'].isna())
print(f"Jumlah anomali: {mask_anomali.sum():,} baris ({mask_anomali.mean()*100:.2f}%)")

# Keputusan Penanganan (Drop Data di bawah 5%)
df = df[(df['emi_ratio'] <= 1)]

df.drop(columns=['monthly_income', 'emi_ratio'], inplace=True)
# Out:
# Jumlah baris EMI > income bulanan: 697 (3.21%)
# Jumlah anomali: 697 baris (3.21%)

# %%
# Bandingkan Monthy_Inhand_Salary dengan Annual_Income
mask_suspicious = (df['Annual_Income'] < df['Monthly_Inhand_Salary'] * 12)

suspicious = df[mask_suspicious]
print(f"\nJumlah baris Annual_Income < income bulanan x 12: {len(suspicious):,} ({len(suspicious)/len(df)*100:.2f}%)")

mask_anomali = (df['Annual_Income'] < df['Monthly_Inhand_Salary'] * 12) | (df['Monthly_Inhand_Salary'].isna())
print(f"Jumlah anomali: {mask_anomali.sum():,} baris ({mask_anomali.mean()*100:.2f}%)")

# Drop Column
df.drop(columns=['Monthly_Inhand_Salary'], inplace=True)
# Out:
# Jumlah baris Annual_Income < income bulanan x 12: 8,628 (41.04%)
# Jumlah anomali: 11,894 baris (56.57%)

# %% [markdown]
# ### **DISTRIBUSI TARGET**

# %%
print(df['Credit_Score'].value_counts())
print(df['Credit_Score'].value_counts(normalize=True))
# Out:
# Credit_Score
# Standard    11201
# Poor         6156
# Good         3667
# Name: count, dtype: int64
# Credit_Score
# Standard    0.532772
# Poor        0.292808
# Good        0.174420
# Name: proportion, dtype: float64

# %% [markdown]
# ## **2. Preprocessing & Pipeline**

# %% [markdown]
# ### **FEATURE ENGINEERING**

# %%
# Mengubah Age Years Menjadi Month
import re

def parse_to_months(text):
    if pd.isna(text):
        return np.nan
    match = re.match(r'(\d+) Years and (\d+) Months', text)
    if match:
        years, months = int(match.group(1)), int(match.group(2))
        return years * 12 + months
    return np.nan

df['Credit_History_Age'] = df['Credit_History_Age'].apply(parse_to_months)

# %%
# Parsing Type_of_Loan
def parse_loans(text):
    if pd.isna(text):
        return []
    cleaned = text.replace(', and ', ', ').replace(' and ', ', ')
    return [loan.strip() for loan in cleaned.split(', ')]

# Cek Unik Loan
all_loans_lists = df['Type_of_Loan'].apply(parse_loans)
unique_loan_types = set()
for loans in all_loans_lists:
    unique_loan_types.update(loans)

print(sorted(unique_loan_types))
# Out:
# ['Auto Loan', 'Credit-Builder Loan', 'Debt Consolidation Loan', 'Home Equity Loan', 'Mortgage Loan', 'Not Specified', 'Payday Loan', 'Personal Loan', 'Student Loan']

# %%
df['Loan_List'] = df['Type_of_Loan'].apply(parse_loans)

loan_types = ['Auto Loan', 'Credit-Builder Loan', 'Debt Consolidation Loan', 'Home Equity Loan', 'Mortgage Loan', 'Not Specified', 'Payday Loan', 'Personal Loan', 'Student Loan']

for loan in loan_types:
    col_name = 'Has_' + loan.replace(' ', '_').replace('-', '_')
    df[col_name] = df['Loan_List'].apply(lambda x: 1 if loan in x else 0)

# Drop kolom yang udah gak dipakai lagi
df.drop(columns=['Type_of_Loan', 'Loan_List'], inplace=True)

# %%
# Encode Target
score_map = {'Poor': 0, 'Standard': 1, 'Good': 2}
df['Credit_Score'] = df['Credit_Score'].map(score_map)

# %% [markdown]
# ### **TRAIN TEST SPLIT**

# %%
input_df=df.drop(['Credit_Score'],axis=1)
output_df=df['Credit_Score']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(input_df, output_df, test_size = 0.2, stratify=output_df, random_state = 42)

# %%
print("x_train size: ", x_train.shape[0])
print("x_test size: ", x_test.shape[0])
print("y_train size: ", y_train.shape[0])
print("y_test size: ", y_test.shape[0])
# Out:
# x_train size:  16819
# x_test size:  4205
# y_train size:  16819
# y_test size:  4205

# %%
num_cols = ['Age', 'Annual_Income', 'Num_Bank_Accounts', 'Num_Credit_Card',
            'Interest_Rate', 'Num_of_Loan', 'Delay_from_due_date',
            'Num_of_Delayed_Payment', 'Changed_Credit_Limit', 'Num_Credit_Inquiries',
            'Outstanding_Debt', 'Credit_Utilization_Ratio', 'Credit_History_Age',
            'Total_EMI_per_month', 'Amount_invested_monthly', 'Monthly_Balance']

bin_cols = ['Has_Auto_Loan', 'Has_Credit_Builder_Loan', 'Has_Debt_Consolidation_Loan',
            'Has_Home_Equity_Loan', 'Has_Mortgage_Loan', 'Has_Not_Specified',
            'Has_Payday_Loan', 'Has_Personal_Loan', 'Has_Student_Loan']

cat_cols = ['Occupation', 'Payment_of_Min_Amount', 'Payment_Behaviour']

ord_cols = ['Credit_Mix']

# %% [markdown]
# ### **PIPELINE**

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

num_preprocess = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('num_scaler', StandardScaler())
])

bin_preprocess = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('bin_encoder', OneHotEncoder(drop='if_binary', handle_unknown='ignore'))
])

cat_preprocess = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('ohe', OneHotEncoder(handle_unknown='ignore'))
])

order_cremix = ['Bad', 'Standard', 'Good', 'Unknown']
ord_preprocess = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('ord_encoder', OrdinalEncoder(categories=[order_cremix]))
])

preprocess = ColumnTransformer(transformers=[
    ('numPreprocess', num_preprocess, num_cols),
    ('binPreprocess', bin_preprocess, bin_cols),
    ('catPreprocess', cat_preprocess, cat_cols),
    ('ordPreprocess', ord_preprocess, ord_cols)
])

# %% [markdown]
# ## **3. MODEL**

# %%
import warnings
warnings.filterwarnings('ignore')

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from lightgbm import LGBMClassifier

models = {
    # --- LOGISTIC REGRESSION ---
    'LR_1': Pipeline([('preprocess', preprocess), ('model', LogisticRegression(C=1.0, solver='lbfgs', class_weight='balanced', random_state=42, max_iter=1000))]),
    'LR_2': Pipeline([('preprocess', preprocess), ('model', LogisticRegression(C=0.1, solver='lbfgs', class_weight='balanced', random_state=42, max_iter=1000))]),
    'LR_3': Pipeline([('preprocess', preprocess), ('model', LogisticRegression(C=1.0, penalty='l1', solver='saga', class_weight='balanced', random_state=42, max_iter=1000))]),
    'LR_4': Pipeline([('preprocess', preprocess), ('model', LogisticRegression(C=0.01, solver='lbfgs', class_weight='balanced', random_state=42, max_iter=1000))]),
    'LR_5': Pipeline([('preprocess', preprocess), ('model', LogisticRegression(C=0.5, penalty='elasticnet', solver='saga', l1_ratio=0.5, class_weight='balanced', random_state=42, max_iter=1000))]),

    # --- RANDOM FOREST ---
    'RF_1': Pipeline([('preprocess', preprocess), ('model', RandomForestClassifier(n_estimators=100, class_weight='balanced', random_state=42, n_jobs=-1))]),
    'RF_2': Pipeline([('preprocess', preprocess), ('model', RandomForestClassifier(n_estimators=300, max_depth=15, class_weight='balanced', random_state=42, n_jobs=-1))]),
    'RF_3': Pipeline([('preprocess', preprocess), ('model', RandomForestClassifier(n_estimators=200, criterion='entropy', class_weight='balanced', random_state=42, n_jobs=-1))]),
    'RF_4': Pipeline([('preprocess', preprocess), ('model', RandomForestClassifier(n_estimators=200, max_depth=10, min_samples_leaf=4, class_weight='balanced', random_state=42, n_jobs=-1))]),
    'RF_5': Pipeline([('preprocess', preprocess), ('model', RandomForestClassifier(n_estimators=500, max_depth=20, max_features='log2', class_weight='balanced', random_state=42, n_jobs=-1))]),

    # --- LIGHTGBM ---
    'LGBM_1': Pipeline([('preprocess', preprocess), ('model', LGBMClassifier(n_estimators=100, max_depth=6, learning_rate=0.3, class_weight='balanced', random_state=42, n_jobs=-1, verbose=-1))]),
    'LGBM_2': Pipeline([('preprocess', preprocess), ('model', LGBMClassifier(n_estimators=300, max_depth=6, learning_rate=0.05, class_weight='balanced', random_state=42, n_jobs=-1, verbose=-1))]),
    'LGBM_3': Pipeline([('preprocess', preprocess), ('model', LGBMClassifier(n_estimators=200, max_depth=10, learning_rate=0.1, class_weight='balanced', random_state=42, n_jobs=-1, verbose=-1))]),
    'LGBM_4': Pipeline([('preprocess', preprocess), ('model', LGBMClassifier(n_estimators=500, max_depth=4, learning_rate=0.01, class_weight='balanced', random_state=42, n_jobs=-1, verbose=-1))]),
    'LGBM_5': Pipeline([('preprocess', preprocess), ('model', LGBMClassifier(n_estimators=400, max_depth=8, learning_rate=0.05, subsample=0.8, colsample_bytree=0.8, class_weight='balanced', random_state=42, n_jobs=-1, verbose=-1))]),
}

# %%
# Cross Validation
from sklearn.model_selection import StratifiedKFold, cross_validate

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
cv_results = []

for name, model in models.items():
    scores = cross_validate(
        model, x_train, y_train, cv=cv,
        scoring='f1_macro',
        n_jobs=-1
    )

    cv_results.append({
        'Model': name,
        'CV F1 Macro Mean': scores['test_score'].mean(),
        'CV F1 Macro Std': scores['test_score'].std()
    })

cv_results_df = pd.DataFrame(cv_results).sort_values(
    by=['CV F1 Macro Mean'], ascending=False
)

cv_results_df
# Out:
#      Model  CV F1 Macro Mean  CV F1 Macro Std
# 7     RF_3          0.710176         0.008738
# 9     RF_5          0.703294         0.007906
# 5     RF_1          0.703221         0.011447
# 12  LGBM_3          0.700581         0.006980
# 14  LGBM_5          0.698856         0.008228
# 6     RF_2          0.693288         0.009273
# 10  LGBM_1          0.692826         0.006009
# 11  LGBM_2          0.691073         0.007934
# 13  LGBM_4          0.670386         0.008439
# 8     RF_4          0.667511         0.010408
# 3     LR_4          0.616248         0.006256
# 4     LR_5          0.615242         0.006154
# 2     LR_3          0.615207         0.006199
# 1     LR_2          0.615188         0.006366
# 0     LR_1          0.615169         0.005546

# %%
best_model_name = cv_results_df.iloc[0]['Model']
print(f"Model Terpilih: {best_model_name}")

best_model = models[best_model_name]
best_model.fit(x_train, y_train)

y_pred = best_model.predict(x_test)
# Out:
# Model Terpilih: RF_3

# %%
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score

print("Accuracy         :", accuracy_score(y_test, y_pred))
print("Precision        :", precision_score(y_test, y_pred, average='macro'))
print("Recall           :", recall_score(y_test, y_pred, average='macro'))
print("F1 Macro         :", f1_score(y_test, y_pred, average='macro'))

print()
print(f"=== CLASSIFICATION REPORT: {best_model_name} ===")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy         : 0.7448275862068966
# Precision        : 0.7293164497692394
# Recall           : 0.7207528729539657
# F1 Macro         : 0.724845417579243
#
# === CLASSIFICATION REPORT: RF_3 ===
#               precision    recall  f1-score   support
#
#            0       0.75      0.73      0.74      1231
#            1       0.77      0.78      0.77      2240
#            2       0.68      0.64      0.66       734
#
#     accuracy                           0.74      4205
#    macro avg       0.73      0.72      0.72      4205
# weighted avg       0.74      0.74      0.74      4205
